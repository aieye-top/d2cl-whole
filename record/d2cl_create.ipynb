# %%
# !mkdir -p d2cl

# %%
# %%writefile d2cl/get_started.md
# # Getting Started
#
# Please first install my favorite package `torch`.
#
# ```{.python .input  n=1}
# !pip install torch
# ```
# Out:
# Writing d2cl/get_started.md

# %%
# %%writefile d2cl/index.md
# # Deploying Demo for d2cl
#
# This is a demo to deploy on Github.
#
# ````toc
# get_started
# ````
# Out:
# Writing d2cl/index.md

# %%
# %%writefile d2cl/config.ini
# [project]
# name = d2cl
#
# [html]
# header_links = PDF, https://aieye-top.github.io/d2cl/d2cl.pdf, fas fa-file-pdf
#
# [deploy]
# github_repo = aieye-top/d2cl
# Out:
# Writing d2cl/config.ini

# %%
# !cd d2cl; d2lbook build html
# Out:
# [d2lbook:config.py:L12] INFO   Load configure from config.ini
# [d2lbook:build.py:L131] INFO   2 notebooks are outdated
# [d2lbook:build.py:L133] INFO   [1] ./get_started.md
# [d2lbook:build.py:L133] INFO   [2] ./index.md
# [d2lbook:build.py:L138] INFO   [1/2, 00:00:00] Evaluating ./get_started.md, save as _build/eval/get_started.ipynb
# [d2lbook:execute.py:L404] INFO   Executing notebook with kernel: python
# [d2lbook:build.py:L145] INFO   Finished in 00:00:06
# [d2lbook:build.py:L138] INFO   [2/2, 00:00:06] Evaluating ./index.md, save as _build/eval/index.ipynb
# [d2lbook:execute.py:L404] INFO   Executing notebook with kernel: python
# [d2lbook:build.py:L145] INFO   Finished in 00:00:01
# [d2lbook:build.py:L49] INFO   === Finished "d2lbook build eval" in 00:00:08
# [d2lbook:build.py:L247] INFO   2 rst files are outdated
# [d2lbook:build.py:L249] INFO   Convert _build/eval/index.ipynb to _build/rst/index.rst
# ...

# %%
# !cd d2cl; d2lbook deploy html
# Out:
# [d2lbook:config.py:L12] INFO   Load configure from config.ini
# Cloning into '/root/mybook/d2cl/_build/github_deploy-git'...
# ...
# fatal: ambiguous argument 'HEAD': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'
# [master (root-commit) ec3e7b0] Version 0.0.1
#  354 files changed, 53299 insertions(+)
#  create mode 100644 .nojekyll
#  create mode 100644 _sources/get_started.rst.txt
#  create mode 100644 _sources/index.rst.txt
#  create mode 100644 _static/basic.css
#  create mode 100644 _static/d2l.css
#  create mode 100644 _static/d2l.js
#  create mode 100644 _static/doctools.js
#  create mode 100644 _static/documentation_options.js
#  create mode 100644 _static/file.png
#  create mode 100644 _static/font/Roboto/Roboto-Regular.eot
#  create mode 100644 _static/font/Roboto/Roboto-Regular.ttf
#  create mode 100644 _static/font/Roboto/Roboto-Regular.woff
# ...
